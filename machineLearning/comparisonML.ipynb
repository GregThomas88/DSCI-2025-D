# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import plotly.express as px
import plotly.graph_objects as go
from sklearn.cluster import DBSCAN

# %%
airports_csv = pd.read_csv('../data/openFlightsRaw/airports.csv')
usRoutes_csv = pd.read_csv('../data/usRoutesClean.csv')


airportsData = airports_csv.merge(usRoutes_csv, how="inner", left_on='AIRPT_ID', right_on='SRC_AIRPT_ID')
airportsData = airportsData[airportsData['CTRY'] == 'United States']

# %%
airportsCoords = airportsData[['LAT', 'LONG']]
airportsCoords = airportsCoords.to_numpy()

# %%
inertiaList = []
kList = range(1, 50)

for k in kList:
    kMeans = KMeans(n_clusters = k, random_state = 0, n_init = 10).fit(airportsCoords)
    inertiaList.append(kMeans.inertia_)

# %%
inertiaDF = pd.DataFrame(inertiaList, columns=['Inertias'])
fig = px.scatter(inertiaDF, y="Inertias")
fig.show()

# %%
airportsData['Kcluster'] = KMeans(n_clusters = 8, random_state = 0, n_init = 10).fit_predict(airportsCoords)
airportsData['KclusterColor'] = airportsData['Kcluster'].map(pd.Series(px.colors.qualitative.Dark24))

# %%
fig = go.Figure()

fig.add_trace(go.Scattergeo(
    name = 'string',
    lat = airportsData['LAT'].tolist(),
    lon = airportsData['LONG'].tolist(), 
    mode = 'markers',
    marker = dict(
        size = 3,
        color = airportsData['KclusterColor'].tolist(),
    ),
))

fig.update_layout(
    title_text='All US Airports have Incoming and Outgoing Traffic',
    showlegend=True,
    geo=dict(
        scope = 'usa',
        showland = True,
        landcolor = 'lightgray',
    )
)

fig.show()

# %%
airportsData[(airportsData['SRCIATA'] == 'LAX') & (airportsData['DESTINIATA'] == 'ATL')]
# Out:
#       AIRPT_ID                               NAME          CTY           CTRY  \
# 1856      3484  Los Angeles International Airport  Los Angeles  United States
# 1871      3484  Los Angeles International Airport  Los Angeles  United States
# 1920      3484  Los Angeles International Airport  Los Angeles  United States
# 1967      3484  Los Angeles International Airport  Los Angeles  United States
# 1985      3484  Los Angeles International Airport  Los Angeles  United States
# 2128      3484  Los Angeles International Airport  Los Angeles  United States
# 2133      3484  Los Angeles International Airport  Los Angeles  United States
# 2148      3484  Los Angeles International Airport  Los Angeles  United States
#
#      IATA  ICAO        LAT        LONG  ALT  TZ  ... SRC_AIRPT_ID  \
# 1856  LAX  KLAX  33.942501 -118.407997  125  -8  ...         3484
# 1871  LAX  KLAX  33.942501 -118.407997  125  -8  ...         3484
# 1920  LAX  KLAX  33.942501 -118.407997  125  -8  ...         3484
# 1967  LAX  KLAX  33.942501 -118.407997  125  -8  ...         3484
# 1985  LAX  KLAX  33.942501 -118.407997  125  -8  ...         3484
# 2128  LAX  KLAX  33.942501 -118.407997  125  -8  ...         3484
# 2133  LAX  KLAX  33.942501 -118.407997  125  -8  ...         3484
# 2148  LAX  KLAX  33.942501 -118.407997  125  -8  ...         3484
#
#                                 SRCNAME DESTIN_AIRPT_ID  \
# 1856  Los Angeles International Airport            3682
# 1871  Los Angeles International Airport            3682
# 1920  Los Angeles International Airport            3682
# 1967  Los Angeles International Airport            3682
# 1985  Los Angeles International Airport            3682
# 2128  Los Angeles International Airport            3682
# 2133  Los Angeles International Airport            3682
# 2148  Los Angeles International Airport            3682
#
#                                             DESTINNAME  seconds   meters  \
# 1856  Hartsfield Jackson Atlanta International Airport    18761   557059
# 1871  Hartsfield Jackson Atlanta International Airport   123304  3761866
# 1920  Hartsfield Jackson Atlanta International Airport    20521   568377
# 1967  Hartsfield Jackson Atlanta International Airport    90352  2720061
# 1985  Hartsfield Jackson Atlanta International Airport    11448   338045
# 2128  Hartsfield Jackson Atlanta International Airport   111045  3348741
# 2133  Hartsfield Jackson Atlanta International Airport    30468   922050
# 2148  Hartsfield Jackson Atlanta International Airport    60328  1887077
#
#       SRCIATA DESTINIATA  Kcluster KclusterColor
# 1856      LAX        ATL         5       #222A2A
# 1871      LAX        ATL         5       #222A2A
# 1920      LAX        ATL         5       #222A2A
# 1967      LAX        ATL         5       #222A2A
# 1985      LAX        ATL         5       #222A2A
# 2128      LAX        ATL         5       #222A2A
# 2133      LAX        ATL         5       #222A2A
# 2148      LAX        ATL         5       #222A2A
#
# [8 rows x 26 columns]
